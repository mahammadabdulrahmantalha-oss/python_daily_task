# %%
import copy

# %%
#1

lists1=[1,2,[3,4],5]

shallow=lists1.copy()

shallow[2][0]=90

print("orginal list  :",lists1)
print("cpoy list     :",shallow)
# Out:
# orginal list  : [1, 2, [90, 4], 5]
# cpoy list     : [1, 2, [90, 4], 5]

# %%
#2

lists1=[1,2,[3,4],5]

shallow=copy.deepcopy(lists1)


print("orginal list  :",lists1)
print("cpoy list     :",shallow)
# Out:
# orginal list  : [1, 2, [3, 4], 5]
# cpoy list     : [1, 2, [3, 4], 5]

# %%
#3
lists=[[1,2,3],[4,5,6],[7,8,9]]
lists2=copy.copy(lists)
print("orginal list  :",lists)
print("cpoy list     :",lists2)
# Out:
# orginal list  : [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# cpoy list     : [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
#4
lists=[[1,2,3],[4,5,6],[7,8,9]]
lists2=copy.deepcopy(lists)
print("orginal list  :",lists)
print("cpoy list     :",lists2)
# Out:
# orginal list  : [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# cpoy list     : [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
#5
dicts={"students" :{"A":1,"B":2,"C":3,"D":4}}

dicts1=copy.copy(dicts)

dicts1["students"]["B"]=6

print("orginal copy  :" ,dicts)
print("cpoy          :" ,dicts1)
# Out:
# orginal copy  : {'students': {'A': 1, 'B': 6, 'C': 3, 'D': 4}}
# cpoy          : {'students': {'A': 1, 'B': 6, 'C': 3, 'D': 4}}

# %%
#6
class person:
    def __init__(self,hobbies):
        
        self.Hobbies=hobbies

    def display_hobbies(self):

        print(f"person hobbis :,{self.Hobbies}")
     # creating the class object   
p1=  person(["playing", "travaling","riding"])
# p1 display hobbies

p1.display_hobbies()
p2=copy.copy(p1)

p2.display_hobbies()

p2.Hobbies[2]="cars"
# Out:
# person hobbis :,['playing', 'travaling', 'riding']
# person hobbis :,['playing', 'travaling', 'riding']
