# %%
# 1
square=lambda x : x*x

square(5)
# Out:
# 25

# %%
#2
cube=lambda x : pow(x,3)

cube(4)
# Out:
# 64

# %%
#3
add=lambda x,y  : (x+y)

add(10,20)
# Out:
# 30

# %%
#4

maxi=lambda *args : max(args)

maxi(2,3,4,36,3,3,5)
# Out:
# 36

# %%
# 5
even_odd=lambda x : " Even" if  x %2==0 else "Odd" 

even_odd(9)
# Out:
# 'Odd'

# %%
#6
numbers=[1,2,3,4]

result=list(map(lambda x : x*x,numbers ))


result
# Out:
# [1, 4, 9, 16]

# %%
#7
numbers=[1,2,3,4,5,6]

result=list(filter(lambda x : x%2==0 , numbers)) 

result
# Out:
# [2, 4, 6]

# %%
#8
numbers=[20,45,55,70]
result=list(filter(lambda x: x>=50, numbers))

result
# Out:
# [55, 70]

# %%
# 9
numbers=[9,5,1,8,2]

result=list(sorted(map( lambda x : x, numbers)))

result
# Out:
# [1, 2, 5, 8, 9]

# %%
# 10

numbers=[9,5,1,8,2]

result=list(reversed(sorted(map(lambda x :x ,numbers))))

result
# Out:
# [9, 8, 5, 2, 1]

# %%
#11

numbers=[10,20,30,40]

result=reduce( lambda x,y : (x+y),numbers)

result
# Out:
# 100

# %%
#12

numbers=[2,3,4,5]

result= reduce(lambda x,y: x*y , numbers)

result
# Out:
# 120

# %%
#13
students=[( "Ram",22),("Amit",19),("Neha",25),("Raj",20)]

result=sorted(students ,key= lambda x :x[1])

result
# Out:
# [('Amit', 19), ('Raj', 20), ('Ram', 22), ('Neha', 25)]

# %%
#14



marks={"A":80,"B":95,"C":70,"D":80}
result=dict(sorted(marks.items ,key= lambda x :x[1]))

print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       1 #14
#       5 marks={"A":80,"B":95,"C":70,"D":80}
# ----> 6 result=dict(sorted(marks.items ,key= lambda x :x[1]))
#       8 print(result)
#
# TypeError: 'builtin_function_or_method' object is not iterable
