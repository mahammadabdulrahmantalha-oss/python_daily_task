# %%
A= ("mohamad abdul rahman")
print(A[0:8])
# Out:
# mohamad

# %%
text= ("full stack data scince")
print(text[-6:])
# Out:
# scince

# %%
text=("full stack data scince")
print(text [2:8])
# Out:
# ll sta

# %%
text=("data scince")
print(text[::2])
# Out:
# dt cne

# %%
text=("mohamad abudl rahman talha")
print(text[0:7])
print(text[8:13])
print(text[14:20])
# Out:
# mohamad
# abudl
# rahman

# %%
text="mohammad abdul rahman talha"
print(text.upper())
# Out:
# MOHAMMAD ABDUL RAHMAN TALHA

# %%
text="mohammad abdul rahman talha"
print(text.lower())
# Out:
# mohammad abdul rahman talha

# %%
text="mohmmad abdul rhaman talha "
print(text.title())
# Out:
# Mohmmad Abdul Rhaman Talha

# %%
text="mohammad abudl rahman talha"
print(text.capitalize())
# Out:
# Mohammad abudl rahman talha
