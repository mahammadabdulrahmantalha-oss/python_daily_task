# %% [markdown]
# # type info funtion

# %%
# type info funtion 
#1
type(10)
type(3.14)
#in typye (10) it is integer int()....and in type (3.14) it is float
# Out:
# float

# %%
#2
len("python")
# out put of len("python") is '6'. it shows the length of the string

len([1,2,3,4,5])
# out put of len([1,2,3,4,5]) is '5'. it shows the length of the list

len((10,20))
#out put of len((10,20)) is '2'. it shows the length of the string

# %%
#3
id(5)
#id means the adderss of the funtion it shows the exact location of the id(5).. its shows where is it stored
#yes some time it stored in same place at memory or it store same two vareabel at same place
# Out:
# 140724155163688

# %%
#4
Age=[32,45,23,34,64,64]
print(type(Age))
#  =LIST
#type() shows type of variable
print(isinstance(Age1,list))
# it shows that if the type is correct or not .. if it is not correct it says FALSE..if it correct its says TRUE
# Out:
# <class 'list'>
# True

# %%
#5
print(len([[1,2],[3,4]]))
# it shows 2 cuz thr len of the list is 2 the both are in same [] so its count as 2 cuz both are in same []
# Out:
# 2

# %% [markdown]
# # Number funtion Q&A
# ##### 6-12

# %%
#6
abs(-25)
# abs change the int if it is negative it change into positive 
abs(7.8)
# it shows same as it is no change in 7.8
# Out:
# 7.8

# %%
#7
lists=(243.432343)
print(round(lists,3))

# in round () it can change the value like u can decide how mnay decimal u can take after (.)point
round(5.4)
# if we not  mention the limit at where u want to stop  it will remove all  decimal
# Out:
# 243.432
# 5

# %%
 #8
pow (3,4)

# pow shows the power of (3)4
pow (2,3%5) # with modulo
# the purpose of the third argument is it divide with the num and then pow we get
# Out:
# 8

# %%
#9
min(10,2,4,63,6,7)
# min () funtion is used to get smallest num in ist
max(-1,-5,0)
# max () funtion is used to get largest num in list
# Out:
# 0

# %%
#10
print(sum([1,2,3,4,5]))
# sum() it will add all num
sum(["1","3"])
# it will not work in list  of string
# Out:
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 4
#       2 print(sum([1,2,3,4,5]))
#       3 # sum()
# ----> 4 sum(["1","3"])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#11
print(max(2,5,25,5,43,7,3))
#max() funtion shows the largest num in list

sorted({2,5,25,5,43,7,3})

#sorted([]) means it sort in order
# Out:
# 43
# [2, 3, 5, 7, 25, 43]

# %%
#12
sum(range(1,11))
# Out:
# 55

# %% [markdown]
# # input / output
# ##### Q&A(13-15)

# %%
#13
print("hello")

print("hello",end=' talha')
# Out:
# hello
# hello talha

# %%
#14
#input() it take int or any thing from user
input("enter the num")
print(int(input()))

#if u take int(input())..... it takes only integer 

#if u take (input())..... it takes only alpha or int
# Out:
# enter the num TALHA
#  568
# 568

# %%
#15
str(input("enter the ur name"))
print(int(input("Age")))
# Out:
# enter the ur name TALHA
# Age 21
# 21

# %% [markdown]
# # type conversion
# ##### Q&A  (16-22)

# %%
#16 
A=("100")
list(A)
float(A)
int=("abc")
list(int)
# Out:
# ['a', 'b', 'c']

# %%
#17
print(str(500))
print(list("helo"))
# Out:
# 500
# ['h', 'e', 'l', 'o']

# %%
#18
tuplee=(1,2,3)
list(tuplee)

set(tuplee)
# Out:
# {1, 2, 3}

# %%
#19
tupl=([1,2,3,3,4])
tupl
# it will print all value
# Out:
# [1, 2, 3, 3, 4]

# %%
#20
set([1,1,2,2,3])
# set only print uniq value
# Out:
# {1, 2, 3}

# %%
#21

bool(0)
bool("")
bool([1])
# Out:
# True

# %%
#22
range(5)
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# # sequece funtion
# #### Q&A(23-27)
