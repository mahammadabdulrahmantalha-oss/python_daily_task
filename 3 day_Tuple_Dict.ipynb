# %% [markdown]
# # DICTIONARY {DICT}

# %%
student={"Name":'talha',"Age":21,"city":'hyd'}
print(student)
# Out:
# {'Name': 'talha', 'Age': 21, 'city': 'hyd'}

# %%
dict={"a":1,"b":2,"c":3}
dict.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
dict={"a":1,"b":2}
dict.values()
# Out:
# dict_values([1, 2])

# %%
student={"Name":'talha',"Age":21,"city":'hyd'}
student.get("Name")
# Out:
# 'talha'

# %%
tup=(12,14,15,20,30,40)
type(tup)
len(tup)
tup1=type(tup),len(tup)
print(tup1)
# Out:
# (<class 'tuple'>, 6)

# %%
tup=(12,14,15,20,30,40)
tup.count(20)
# Out:
# 1

# %%
tup=(12,14,15,20,30,40)
tup.index(30)
# Out:
# 4

# %%
dict={}
dict.update({"a":1,"b":2,"c":3})
print(dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
dict={"a":1,"b":2,"c":3}
dict.update({"d":4})
print(dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
dict={"Name":'talha',"Age":21,"city":'hyd'}
dict.pop('Age')
dict
# Out:
# {'Name': 'talha', 'city': 'hyd'}

# %%
dict={"x":1,"y":2,"z":3}
dict.popitem()
print(dict.popitem())
# Out:
# ('y', 2)

# %%
#dict.fromkey(key,value)

dict1=["Red","Green","blue"]
dict1=dict.fromkeys(dict1,0)
dict1
# Out:
# {'Red': 0, 'Green': 0, 'blue': 0}

# %%
dict={"a":1,"b":2,"c":3}
dict.copy()
# Out:
# {'a': 1, 'b': 2, 'c': 3}
