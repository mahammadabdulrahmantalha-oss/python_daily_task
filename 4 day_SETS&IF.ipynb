# %% [markdown]
# ### SET AND IF Q

# %%
#1
set={1,2,3,4,5,1,2}
set
# Out:
# {1, 2, 3, 4, 5}

# %%
#2
A=set()
A.add(1)
A.add(2)
A.add(3)
A
# Out:
# {1, 2, 3}

# %%
#3
s={10,20,30}
s.update([40,50,25])
s
# Out:
# {10, 20, 25, 30, 40, 50}

# %%
#4
s={10,20, 30, 40, 50, 60}
s.remove(20)
s.discard(20)
s
#by remove syntax we can remove the element but if the element is not present in set it will show as ERROR .. 
# but with discard it will not show any error
# Out:
# {10, 30, 40, 50, 60}

# %%
#5
A={1,2,3,4}
B={4,7,8,9,}
print(A.intersection(B))
print(A.union(B))
print(A.difference(B))
# Out:
# {4}
# {1, 2, 3, 4, 7, 8, 9}
# {1, 2, 3}

# %%
#6
s={10, 20, 30, 40, 50}
25 in s
# Out:
# False

# %%
#7
list1=[1,2,2,4,5,6,7]
print(set(list1))      
print(len(set(list1)))
# Out:
# {1, 2, 4, 5, 6, 7}
# 6

# %%
#8
sets=set()
for i in range (5):
    A=(input("enter the number"))
    sets.update(A)
# Out:
# enter the number 1
# enter the number 2
# enter the number 3
# enter the number 4
# enter the number 6

# %%
sets
# Out:
# {'1', '2', '3', '4', '6'}

# %%
#9
A={1,2,3,4}
B={4,7,8,9,}
print(B.difference(A))
# Out:
# {8, 9, 7}

# %%
#10
set1={1,2,3,4,}
list1=[6,7,8]
set1.add(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 set1={1,2,3,4,}
#       2 list1=[6,7,8]
# ----> 3 set1.add(list1)
#
# TypeError: unhashable type: 'list'

# %%
#11
Age=int(input("enter ur age"))
if Age>=18:
    print("ur eligible to vote")
# Out:
# enter ur age 20
# ur eligible to vote

# %%
#12 
number=(int(input()))
if number>0:
    print("positive");
elif number==0:
    print("zero")
else :
    print("negative")
# Out:
#  9
# positive

# %%
#13
a=2
b=4
if a<b:
    print("large")
else :
    print("small")
# Out:
# large

# %%
#14
A= "a"
vowel="a,e,i,o,u"
if A in vowel:
    print("yes")
else :
    print("no")
# Out:
# yes

# %%
A=str(input())
V="a,e,i,o,u"
if A in V:
    print("vowel")
else : 
    print("no vowel found")
# Out:
#  f
# no vowel found

# %%
# 15
A=int(input())
if A>=90:
    print("A+")
elif A>=80:
    print("B")
else :
    print("fail")
# Out:
#  85
# B
