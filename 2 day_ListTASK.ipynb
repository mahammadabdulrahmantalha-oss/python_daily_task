# %%
#list

# %%
student=["talha","sofiyan","ibrahim","almas","fahad"]
print(student)
# Out:
# ['talha', 'sofiyan', 'ibrahim', 'almas', 'fahad']

# %%
numbers=["10","20","30","40","50"]
print(type(numbers))
print(len(numbers))
# Out:
# <class 'list'>
# 5

# %%
list=[]
list.append(10)
list.append(20)
list.append(30)
print(list)
# Out:
# [10, 20, 30]

# %%
list1=[1,2,3]
list2=[4,5,6]
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list=[10,20,30,40]
list.insert(2,100)
list
# Out:
# [10, 20, 100, 30, 40]

# %%
list=[10,20,30,40,50,50]
list.remove(50)
list
# Out:
# [10, 20, 30, 40, 50]

# %%
list=[10,20,30,50]
list.pop()
list
# Out:
# [10, 20, 30]

# %%
data=[1,2,3,4,5]
data.clear()
data
# Out:
# []

# %%
list=[10,15,25,30,40]
list=list.index(25)
list
# Out:
# 2

# %%
list=[7,2,7,5,7,8]
list.count(7)
# Out:
# 3

# %%
list=[45,12,78,23,56]
list.sort()
list
# Out:
# [12, 23, 45, 56, 78]

# %%
list=[45,12,78,23,56]
list.sort(reverse=True)
list
# Out:
# [78, 56, 45, 23, 12]

# %%
list=["appel","banana","mango","orange"]
list.reverse()
list
# Out:
# ['orange', 'mango', 'banana', 'appel']

# %%
list1=[1,2,3,4]
list2=list1.copy()
print(list1)
print(list2)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
text=(input("enter the text"))
word_list=text.split()
print(word_list)
# Out:
# enter the text i love programming
# ['i', 'love', 'programming']

# %%
list=[1,2,3,4,5]
list.append(6)
list.append(7)
list.append(8)
list.sort(reverse=True)
list
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
list=["java","html"]
list.insert(0,"python")
list.pop()
list
# Out:
# ['python', 'java']

# %%
city=[input("enter the city"),
    input("enter the city"),
    input("enter the city"),
    input("enter the city"),
    input("enter the city")]
city.reverse()
city
# Out:
# enter the city hyd
# enter the city nzb
# enter the city bhodan
# enter the city nirmal
# enter the city armoor
# ['armoor', 'nirmal', 'bhodan', 'nzb', 'hyd']

# %%
data=[10,20,30,40,20]
data.remove(20)
data.remove(20)
data
# Out:
# [10, 30, 40]

# %%
marks=[40,50,80,10,20,34,26,70]
marks.sort()
highest=marks[-1]
lowest=marks[0]
marks
# Out:
# [10, 20, 26, 34, 40, 50, 70, 80]

# %%
highest
# Out:
# 80
